# %%
n = int(input())
print(2*n)
# Out:
#  3
# 6

# %%
a = float(input())
b = float(input())

pi = 3.14
r = min(a, b) / 2
dien_tich = a*b - pi*r*r

print(f"{dien_tich:.2f}")
# Out:
#  3
#  4
# 4.94

# %%
c = input()

if 'A' <= c <= 'Z':
    print(chr(ord(c) + 32))
elif 'a' <= c <= 'z':
    print(chr(ord(c) - 32))
# Out:
#  r
# R

# %%
c = input()

if ('A' <= c <= 'Z') or ('a' <= c <= 'z'):
    print(f"{c} la ki tu alphabet")
else:
    print(f"{c} khong phai la ki tu alphabet")
# Out:
#  r
# r la ki tu alphabet

# %%
c = input()

if c == 'A':
    print('z')
else:
    print(chr(ord(c.lower()) - 1))
# Out:
#  r
# q

# %%
import math

a = float(input())
b = float(input())
c = float(input())

if a+b > c and a+c > b and b+c > a:
    p = (a+b+c)/2
    s = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print(f"{s:.1f}")
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
#  4
#  5
#  6
# 9.9

# %%
s = input()

if len(s) >= 20:
    print(s[4], s[5])
# Out:
#  1234567892345678345678
# 5 6

# %%
ten = input()
chi_cu = int(input())
chi_moi = int(input())

dien = chi_moi - chi_cu
tien = 0

if dien > 0:
    if dien <= 50:
        tien += dien * 1984
    else:
        tien += 50 * 1984
        dien -= 50

    if dien > 0:
        if dien <= 50:
            tien += dien * 2050
        else:
            tien += 50 * 2050
            dien -= 50

    if dien > 0:
        if dien <= 100:
            tien += dien * 2380
        else:
            tien += 100 * 2380
            dien -= 100

    if dien > 0:
        if dien <= 100:
            tien += dien * 2998
        else:
            tien += 100 * 2998
            dien -= 100

    if dien > 0:
        if dien <= 100:
            tien += dien * 3350
        else:
            tien += 100 * 3350
            dien -= 100

    if dien > 0:
        tien += dien * 3460

tien = int(tien * 1.08)

print("Ho va ten:", ten)
print("Tien phai tra la:", tien)
# Out:
#  duc
#  2313
#  313
# Ho va ten: duc
# Tien phai tra la: 0
