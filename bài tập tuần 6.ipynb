# %%
b=list(map(int,input().split()))
c=[]
for x in b:
    if x not in c:
        c.append(x)
    else:
        break
print(c)
# Out:
#  3 2 1 1 2 3
# [3, 2, 1]

# %%
b=list(map(int,input().split()))
c=[]
d=0
for x in b:
    d+=x
    c.append(d)
print(c)
# Out:
#  1 1 1 1 1
# [1, 2, 3, 4, 5]

# %%
b=list(map(int,input().split()))
k=input()
c=[]
for z in range(int(k),len(b)):
    c.append(b[z])
for i in range(0,int(k)):
    c.append(b[i])
print(c)
# Out:
#  1 2 3 4 5
#  3
# [4, 5, 1, 2, 3]

# %%
b=input().split()
c={}
for x in b:
    key,value=x.split(':')
    if key not in c:
        c[key]=[value]
    else:
        c[key].append(value)
print(c)
# Out:
#  a:1 b:2 a:3 c:4 b:5 a:6
# {'a': ['1', '3', '6'], 'b': ['2', '5'], 'c': ['4']}

# %%
b=input().split()
c={'positive':0,'negative':0,'zeros':0}
for x in b:
    if int(x)>0:
        c['positive']+=1
    if int(x)<0:
        c['negative']+=1
    if int(x)==0:
        c['zeros']+=1
print(c)
# Out:
#  3 4 5 -2 1 0
# {'positive': 4, 'negative': 1, 'zeros': 1}

# %%
a=list(map(int,input().split()))
b=0
for x in a:
    b+=x
print(b)
# Out:
#  3 4 5
# 12

# %%
a=list(map(int,input().split()))
b=[]
for x in a:
    b.append(a[(-a.index(int(x)))-1])
c=tuple(b)
print(a[0],a[-1],c)
# Out:
#  1 2 3 4 5
# 1 5 (5, 4, 3, 2, 1)

# %%
a=input().split()
b={}
for x in a:
    if x not in b:
        b[x]=a.count(x)
print(b)
# Out:
#  1 1 2 2
# {'1': 2, '2': 2}

# %%
a=input().split()
b=input().split()
c={}
d={}
for x in a:
    key,value1=x.split(':')
    c[key]=[value1]
for x in b:
    key,value2=x.split(':')    
    d[key]=[value2]
if key in c and key not in d:
        c[key]=[value1]
if key in d and key not in c:
        c[key]=[value2]
if key in c and key in d:
        c[key]=[int(value1)+int(value2)]
print(c)
# Out:
#  a:1
#  a:1
# {'a': [2]}

# %%
a=input().split()
chan=[]
le=[]
for x in a:
    if int(x)%2==0:
        chan.append(x)
    else:
        le.append(x)
print(chan,le)
# Out:
#  1 2 3 4 5 6 7
# ['2', '4', '6'] ['1', '3', '5', '7']

# %%
a=list(map(int,input().split()))
b=[]
for x in a:
    b.append(a.count(x))
print(a[b.index(max(b))])
# Out:
#  1 1 1 2 3 1
# 1

# %%
a=input().split()
b=input().split()
c=[]
for x in a:
    c.append(x)
for y in c:
    if y not in b:
        c.remove(y)
print(c)
# Out:
#  3 4 5 6 7
#  4 5 6 7 8
# ['4', '5', '6', '7']

# %%
a=input().split()
k=input()
d={}
for x in a:
    key,value1=x.split(':')
    c[key]=[value1]
if value1<k:
    c.remove(c[key])
# Out:
#  a:2 B:3 c:4
#  3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 for x in a:
#       5     key,value1=x.split(':')
# ----> 6     c[key]=[value1]
#       7 if value1<k:
#       8     c.remove(c[key])
#
# TypeError: list indices must be integers or slices, not str
